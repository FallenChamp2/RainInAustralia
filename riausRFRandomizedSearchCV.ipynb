# %%
import pandas as pd
import numpy as np

RIAUS = pd.read_csv(r'../input/weather-dataset-rattle-package/weatherAUS.csv')
RIAUS.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
RIAUS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
RIAUS.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
RIAUS['WindGustDir'].unique()
# Out:
# array(['W', 'WNW', 'WSW', 'NE', 'NNW', 'N', 'NNE', 'SW', nan, 'ENE',
#        'SSE', 'S', 'NW', 'SE', 'ESE', 'E', 'SSW'], dtype=object)

# %%
RIAUS['WindDir9am'].unique()
# Out:
# array(['W', 'NNW', 'SE', 'ENE', 'SW', 'SSE', 'S', 'NE', nan, 'SSW', 'N',
#        'WSW', 'ESE', 'E', 'NW', 'WNW', 'NNE'], dtype=object)

# %%
RIAUS['WindDir3pm'].unique()
# Out:
# array(['WNW', 'WSW', 'E', 'NW', 'W', 'SSE', 'ESE', 'ENE', 'NNW', 'SSW',
#        'SW', 'SE', 'N', 'S', 'NNE', nan, 'NE'], dtype=object)

# %%
RIAUS['RainToday'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
RIAUS['RainTomorrow'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
RIAUS.dropna(inplace = True)

# %%
RIAUS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56420 entries, 6049 to 142302
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           56420 non-null  object
#  1   Location       56420 non-null  object
#  2   MinTemp        56420 non-null  float64
#  3   MaxTemp        56420 non-null  float64
#  4   Rainfall       56420 non-null  float64
#  5   Evaporation    56420 non-null  float64
#  6   Sunshine       56420 non-null  float64
#  7   WindGustDir    56420 non-null  object
#  8   WindGustSpeed  56420 non-null  float64
#  9   WindDir9am     56420 non-null  object
#  10  WindDir3pm     56420 non-null  object
#  11  WindSpeed9am   56420 non-null  float64
#  12  WindSpeed3pm   56420 non-null  float64
#  13  Humidity9am    56420 non-null  float64
#  14  Humidity3pm    56420 non-null  float64
#  15  Pressure9am    56420 non-null  float64
#  16  Pressure3pm    56420 non-null  float64
# ...

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
k = RIAUS['WindGustDir']
RIAUS['WindGustDir'] = encoder.fit_transform(k)

# %%
k = RIAUS['WindDir9am']
RIAUS['WindDir9am'] = encoder.fit_transform(k)

k = RIAUS['WindDir3pm']
RIAUS['WindDir3pm'] = encoder.fit_transform(k)

k = RIAUS['RainToday']
RIAUS['RainToday'] = encoder.fit_transform(k)

k = RIAUS['RainTomorrow']
RIAUS['RainTomorrow'] = encoder.fit_transform(k)

k = RIAUS['Location']
RIAUS['Location'] = encoder.fit_transform(k)

# %%
RIAUS.head()
# Out:
#             Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 6049  2009-01-01         4     17.9     35.2       0.0         12.0      12.3
# 6050  2009-01-02         4     18.4     28.9       0.0         14.8      13.0
# 6052  2009-01-04         4     19.4     37.6       0.0         10.8      10.6
# 6053  2009-01-05         4     21.9     38.4       0.0         11.4      12.2
# 6054  2009-01-06         4     24.2     41.0       0.0         11.2       8.4
#
#       WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  Humidity3pm  \
# 6049           11           48.0           1  ...         20.0         13.0
# 6050            8           37.0          10  ...         30.0          8.0
# 6052            5           46.0           5  ...         42.0         22.0
# 6053           14           31.0          14  ...         37.0         22.0
# 6054           14           35.0           7  ...         19.0         15.0
#
# ...

# %%
Date = pd.to_datetime(RIAUS['Date'], infer_datetime_format = True)

# %%
X = RIAUS.iloc[ : , 1 : 22]

# %%
X = X[ : 2000]

# %%
X['Evap - Sun'] = X['Evaporation'] - X['Sunshine']

# %%
X['WS * Cloud3pm * Sunshine * MinTemp'] = X['WindSpeed3pm'] * X['Sunshine'] * X['Cloud3pm'] * X['MinTemp']

# %%
X['MaxT - MinT'] = X['MaxTemp'] - X['MinTemp']

# %%
X['WindDir'] = X['WindDir3pm'] - X['WindDir9am']

# %%
X['WindSpeed'] = X['WindSpeed3pm'] - X['WindSpeed9am']

# %%
X['Humidity'] = X['Humidity3pm'] - X['Humidity9am']

# %%
X['Pressure'] = X['Pressure3pm'] - X['Pressure9am']

# %%
X['Cloud'] = X['Cloud3pm'] - X['Cloud9am']

# %%
X['Temp'] = X['Temp3pm'] - X['Temp9am']

# %%
X.head()
# Out:
#       Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 6049         4     17.9     35.2       0.0         12.0      12.3
# 6050         4     18.4     28.9       0.0         14.8      13.0
# 6052         4     19.4     37.6       0.0         10.8      10.6
# 6053         4     21.9     38.4       0.0         11.4      12.2
# 6054         4     24.2     41.0       0.0         11.2       8.4
#
#       WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  ...  RainToday  \
# 6049           11           48.0           1          12  ...          0
# 6050            8           37.0          10          10  ...          0
# 6052            5           46.0           5           6  ...          0
# 6053           14           31.0          14          15  ...          0
# 6054           14           35.0           7          14  ...          0
#
#       Evap - Sun  WS * Cloud3pm * Sunshine * MinTemp  MaxT - MinT  WindDir  \
# ...

# %%
X['Month'] = Date.dt.month

# %%
X['Year'] = Date.dt.year

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 6049 to 12154
# Data columns (total 32 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Location                            2000 non-null   int64
#  1   MinTemp                             2000 non-null   float64
#  2   MaxTemp                             2000 non-null   float64
#  3   Rainfall                            2000 non-null   float64
#  4   Evaporation                         2000 non-null   float64
#  5   Sunshine                            2000 non-null   float64
#  6   WindGustDir                         2000 non-null   int64
#  7   WindGustSpeed                       2000 non-null   float64
#  8   WindDir9am                          2000 non-null   int64
#  9   WindDir3pm                          2000 non-null   int64
#  10  WindSpeed9am                        2000 non-null   float64
# ...

# %%
X.head()
# Out:
#       Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 6049         4     17.9     35.2       0.0         12.0      12.3
# 6050         4     18.4     28.9       0.0         14.8      13.0
# 6052         4     19.4     37.6       0.0         10.8      10.6
# 6053         4     21.9     38.4       0.0         11.4      12.2
# 6054         4     24.2     41.0       0.0         11.2       8.4
#
#       WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  ...  \
# 6049           11           48.0           1          12  ...
# 6050            8           37.0          10          10  ...
# 6052            5           46.0           5           6  ...
# 6053           14           31.0          14          15  ...
# 6054           14           35.0           7          14  ...
#
#       WS * Cloud3pm * Sunshine * MinTemp  MaxT - MinT  WindDir  WindSpeed  \
# 6049                            22017.00         17.3       11       14.0
# ...

# %%
K = X

# %%
#K.drop(['WindDir9am', 'WindDir3pm', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 
         #'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm'], inplace = True, axis = 1)

# %%
y = RIAUS['RainTomorrow']

# %%
y = y[ : 2000]

# %%
K.head()
# Out:
#       Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 6049         4     17.9     35.2       0.0         12.0      12.3
# 6050         4     18.4     28.9       0.0         14.8      13.0
# 6052         4     19.4     37.6       0.0         10.8      10.6
# 6053         4     21.9     38.4       0.0         11.4      12.2
# 6054         4     24.2     41.0       0.0         11.2       8.4
#
#       WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  ...  \
# 6049           11           48.0           1          12  ...
# 6050            8           37.0          10          10  ...
# 6052            5           46.0           5           6  ...
# 6053           14           31.0          14          15  ...
# 6054           14           35.0           7          14  ...
#
#       WS * Cloud3pm * Sunshine * MinTemp  MaxT - MinT  WindDir  WindSpeed  \
# 6049                            22017.00         17.3       11       14.0
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaled_data = scaler.fit_transform(K)
K = scaled_data

# %%
from sklearn.decomposition import PCA

pca2 = PCA(n_components = 10)
components2 = pca2.fit_transform(K)
components2_df = pd.DataFrame(components2)

# %%
from sklearn.model_selection import cross_val_score, KFold, StratifiedKFold, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

model = RandomForestClassifier()

parameters = {
            'n_estimators' : [int(x) for x in np.linspace(200, 2000, 10)],
            'max_features' : ['sqrt', 'log2', 'auto'],
            'max_depth' : [int(x) for x in np.arange(10, 100, 10)],
            'min_samples_split' : [2, 5, 10],
            'min_samples_leaf' : [1, 2, 4],
            'bootstrap' : [True, False]
}


RFCV = RandomizedSearchCV(estimator = model, param_distributions = parameters, n_iter = 5, cv = 5, verbose = 2,
                          n_jobs = -1)

RFCV.fit(components2_df, y)

print('Best parameters :', RFCV.best_params_)
print('Best estimator :', RFCV.best_estimator_)
print('Best match :', RFCV.best_score_)
print('Full :', RFCV.best_estimator_.get_params())
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:  1.1min finished
# Best parameters : {'n_estimators': 1200, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'auto', 'max_depth': 80, 'bootstrap': True}
# Best estimator : RandomForestClassifier(max_depth=80, min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=1200)
# Best match : 0.8114999999999999
# Full : {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 80, 'max_features': 'auto', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 1200, 'n_jobs': None, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}

# %%
#import eli5
#from eli5.sklearn import PermutationImportance

#model.fit(K, y)

#perm = PermutationImportance(model, random_state = 1).fit(K, y)

# %%
#eli5.show_weights(perm, feature_names = X.columns.tolist())

# %%
#w = eli5.show_weights(perm, feature_names = X.columns.tolist(), top = 30)
#result = pd.read_html(w.data)[0]
#result

# %%
#from sklearn.decomposition import PCA

#pca = PCA()

#components = pca.fit_transform(K)
#components_df = pd.DataFrame(components)

# %%
#EVR = pd.DataFrame(pca.explained_variance_ratio_)
#EVR.plot(kind = 'bar')

# %%
#pca2 = PCA(n_components = 10)
#components2 = pca2.fit_transform(K)
#components2_df = pd.DataFrame(components2)
# Out:
# [CV] n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20, bootstrap=True
# [CV]  n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20, bootstrap=True, total=   4.5s
# [CV] n_estimators=1600, min_samples_split=10, min_samples_leaf=2, max_features=log2, max_depth=10, bootstrap=True
# [CV]  n_estimators=1600, min_samples_split=10, min_samples_leaf=2, max_features=log2, max_depth=10, bootstrap=True, total=  10.4s
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=2, max_features=log2, max_depth=10, bootstrap=False
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=2, max_features=log2, max_depth=10, bootstrap=False, total=   7.0s
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=2, max_features=log2, max_depth=10, bootstrap=False
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=2, max_features=log2, max_depth=10, bootstrap=False, total=   7.2s
# ...
